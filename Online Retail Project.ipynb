# %%
from sklearn.metrics import silhouette_score
from sklearn import cluster,datasets
from sklearn.preprocessing import StandardScaler
from matplotlib.lines import Line2D

# %%
n_samples=1500
X,y=datasets.make_moons(n_samples,noise=0.05)



X=StandardScaler().fit_transform(X)

# %%
from sklearn import datasets

data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

X=StandardScaler().fit_transform(X)

# %%
single=cluster.AgglomerativeClustering(2,linkage='single')

# %%
kmeans=cluster.KMeans(8)

# %%
single.fit(X)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
y1_pred = single.labels_.astype(int)
y2_pred = kmeans.predict(X)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig,ax=plt.subplots(1,2,figsize=(12,6)) # 1 row 2 columns
colors = np.array(['blue','red'])
ax[0].scatter(X[:,0],X[:,1],c=colors[y1_pred])
ax[1].scatter(X[:,0],X[:,1],c=y2_pred)
legend_elems = [Line2D([0], [0], color=color, marker='o', linestyle='', label="Predicted Class {}".format(i))
                for i, color in enumerate(colors)]
ax[0].scatter(X[:, 0], X[:, 1], color=colors[y1_pred])
ax[0].legend(handles=legend_elems, loc='upper right')
ax[1].scatter(X[:, 0], X[:, 1], color=colors[y2_pred])
ax[1].legend(handles=legend_elems, loc='upper right')

# %%
print(silhouette_score(X,y1_pred))
print(silhouette_score(X,y2_pred))
# Out:
# 0.22245060727650934
# 0.14654134706026087

# %%
from yellowbrick.cluster import KElbowVisualizer

# %%
import pandas as pd
model =cluster.KMeans()
visualizer=KElbowVisualizer(model,k=(4,12))
visualizer.fit(X)
visualizer.poof
# Out:
# <bound method Visualizer.poof of KElbowVisualizer(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7fa76e235b38>,
#                  k=None, metric=None, model=None, timings=True)>

# %%
X = pd.DataFrame(X)
X

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
X, _ = make_blobs(n_samples=1500, centers=4, cluster_std=1.5)
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
y_pred = kmeans.predict(X)
plt.figure(figsize=(6,6))
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=50, alpha=0.75)
plt.show()

# %%
from sklearn.datasets import make_blobs
from mpl_toolkits.mplot3d import Axes3D
from scipy.spatial.transform import Rotation as R
X, _ = make_blobs(n_samples=500, n_features=2, centers=3, cluster_std=1.0)
X = np.c_[X, 0.5 * np.random.randn(X.shape[0], 1)]
rot = R.from_euler('y', 45, degrees=True)
X = rot.apply(X)
fig = plt.figure(figsize=(8, 8))
ax = fig.gca(projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2])
ax.set_xlim(-7, 7)
ax.set_ylim(-7, 7)
ax.set_zlim(-7, 7)
ax.view_init(elev=20, azim=65)
plt.show()

# %%
from sklearn import datasets

data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

# %%
X=StandardScaler().fit_transform(X)
single=cluster.AgglomerativeClustering(2,linkage='single')

# %%
kmeans=cluster.KMeans(2)
y1_pred = single.labels_.astype(int)
y2_pred = kmeans.predict(X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-fd7e98ff7641> in <module>()
#       1 kmeans=cluster.KMeans(2)
# ----> 2 y1_pred = single.labels_.astype(int)
#       3 y2_pred = kmeans.predict(X)
#
# AttributeError: 'AgglomerativeClustering' object has no attribute 'labels_'

# %%
single.fit(X)
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
print(silhouette_score(X,y1_pred))
print(silhouette_score(X,y2_pred))

# %%
data = datasets.load_wine()

X = pd.DataFrame(data["data"], columns=data["feature_names"])
y = pd.Series(data["target"])

# %%
X=StandardScaler().fit_transform(X)
kmeans=cluster.KMeans(3)
kmeans.fit(X)
y2_pred = kmeans.predict(X)
print(silhouette_score(X,y2_pred))
# Out:
# 0.2848589191898987

# %%
from yellowbrick.cluster import KElbowVisualizer

import pandas as pd
model =cluster.KMeans()
visualizer=KElbowVisualizer(model,k=(4,12))
visualizer.fit(X)
visualizer.poof
# Out:
# <bound method Visualizer.poof of KElbowVisualizer(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7fa76e1a6da0>,
#                  k=None, metric=None, model=None, timings=True)>

# %%
single=cluster.AgglomerativeClustering(2,linkage='single')

single.fit(X)


y1_pred = single.labels_.astype(int)
print(silhouette_score(X,y1_pred))
# Out:
# 0.6867350732769776

# %%
from sklearn.manifold import TSNE

colors = np.array(['blue','red','violet'])
fig, ax = plt.subplots(1, 4, figsize=(15, 7))
for i, perp in enumerate([5, 30, 50, 100]):
    tsne = TSNE(perplexity=perp)
    x_embedded = tsne.fit_transform(X)
    ax[i].scatter(x_embedded[:, 0], x_embedded[:, 1], c=colors[y])
    ax[i].set_title("Perplexity = {}".format(perp))
    
plt.show()

# %%
import pandas as pd
df = pd.read_csv('Online Retail.csv',encoding = "ISO-8859-1")

# %%
df.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %%
df.StockCode.value_counts()

# %%
df1.shape
# Out:
# (285953, 9)

# %%
df1=df.dropna()

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
df.StockCode.nunique()
# Out:
# 4070

# %%
df1['Item_Class'] = df1['Description']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df1['Description'] = df1.Description.str.lower()
#df1.Description
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
import numpy as np

# %%
#df1['Item_Class'] = np.where(df1['Description'].str.contains("bag", case=False, na=False), 'bag','')
#ça ne marche que pour une colonne booleans

# %%
import os
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop = stopwords.words('english')

# %%
len(stop)
# Out:
# 179

# %%
df1['Description'] = df1['Description']
.apply(lambda x: ' '.join([item for item 
 in x.split() if item not in stop]))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
pd.Series([j for i in df1.Description.str.
           lower().str.split() for j in i]).value_counts()

# %%
df1['Item_Class'] = df1['Description']
df1.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#   InvoiceNo StockCode  ...         Country                           Item_Class
# 0    536365    85123A  ...  United Kingdom   white hanging heart t-light holder
# 1    536365     71053  ...  United Kingdom                  white metal lantern
# 2    536365    84406B  ...  United Kingdom       cream cupid hearts coat hanger
# 3    536365    84029G  ...  United Kingdom  knitted union flag hot water bottle
# 4    536365    84029E  ...  United Kingdom       red woolly hottie white heart.
#
# [5 rows x 9 columns]

# %%
df1.Item_Class=df1.Description.apply(lambda x: np.where('retrospot' in x,'retrospot',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('vintage' in x,'vintage',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('card' in x,'accessory',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('holder' in x,'accessory',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('set' in x,'set',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('bag' in x,'bag',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('sign' in x,'decoration',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('christmas' in x,'decoration',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('decoration' in x,'decoration',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('design' in x,'decoration',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('cases' in x,'boxes',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('box' in x,'boxes',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('cakestand' in x,'home',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('ornament' in x,'home',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('bunting' in x,'miscellaneous',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('heart' in x,'home',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('postage' in x,'accessory',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('light' in x,'home',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('frame' in x,'decoration',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('bottle' in x,'home',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('clock' in x,'home',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('pad' in x,'home',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('carry' in x,'accessory',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('teacup' in x,'home',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('charm' in x,'home',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('home' in x,'home',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('calm' in x,'accessory',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('kitchen' in x,'home',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('friends' in x,'miscellaneous',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('tin' in x,'home',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('clock' in x,'home',x))
df1.Item_Class=df1.Item_Class.apply(lambda x: np.where('doormat' in x,'home',x))

#other_food = [x for x in df.Item.unique() if x not in beverage 
 #               and x not in other and x not in kids and x not in snacks 
  #              and x not in bread and x not in breakfast_pastry 
   #             and x not in dessert and x not in condiments 
    #            and x not in breakfast and x not in lunch]
# si on veut mettre tout le reste dans une même section sans distinguer
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df1 = df1[df1.Item_Class != df1.Description]
df1 = df1.drop(['Description'],axis=1)
df1.head()
# Out:
#   InvoiceNo StockCode  Quantity  ... CustomerID         Country  Item_Class
# 0    536365    85123A         6  ...    17850.0  United Kingdom   accessory
# 2    536365    84406B         8  ...    17850.0  United Kingdom        home
# 3    536365    84029G         6  ...    17850.0  United Kingdom        home
# 4    536365    84029E         6  ...    17850.0  United Kingdom        home
# 5    536365     22752         2  ...    17850.0  United Kingdom         set
#
# [5 rows x 8 columns]

# %%
df1=pd.get_dummies(data=df1, columns=['Item_Class'])
df1.head()
# Out:
#   InvoiceNo StockCode  ...  Item_Class_set Item_Class_vintage
# 0    536365    85123A  ...               0                  0
# 2    536365    84406B  ...               0                  0
# 3    536365    84029G  ...               0                  0
# 4    536365    84029E  ...               0                  0
# 5    536365     22752  ...               1                  0
#
# [5 rows x 16 columns]

# %%
df1['day']=df.InvoiceDate.dt.day_name()
df1['hour']=df1.InvoiceDate.dt.hour
df1=pd.get_dummies(data=df1, columns=['day'])
df1.drop('InvoiceDate',inplace=True,axis=1)
df1.head()
# Out:
#   InvoiceNo StockCode  Quantity  ...  day_Thursday  day_Tuesday day_Wednesday
# 0    536365    85123A         6  ...             0            0             1
# 2    536365    84406B         8  ...             0            0             1
# 3    536365    84029G         6  ...             0            0             1
# 4    536365    84029E         6  ...             0            0             1
# 5    536365     22752         2  ...             0            0             1
#
# [5 rows x 22 columns]

# %%
df1['Item_Class_accessory'] = df1['Item_Class_accessory'] * df1.Quantity
df1['Item_Class_bag']=df1['Item_Class_bag'] * df1.Quantity
df1['Item_Class_boxes']=df1['Item_Class_boxes']* df1.Quantity
df1['Item_Class_decoration'] =df1['Item_Class_decoration'] * df1.Quantity
df1['Item_Class_home'] =df1['Item_Class_home'] * df1.Quantity
df1['Item_Class_miscellaneous'] = df1['Item_Class_miscellaneous']* df1.Quantity
df1['Item_Class_retrospot'] =df1['Item_Class_retrospot']  * df1.Quantity
df1['Item_Class_set'] = df1['Item_Class_set']* df1.Quantity
df1['Item_Class_vintage'] = df1['Item_Class_vintage'] * df1.Quantity
df1['UnitPrice'] = df1['UnitPrice'] * df1.Quantity
df1.rename(columns= {'UnitPrice': 'AmountSpent'},inplace=True)

df1 = df1[df1.Country == 'United Kingdom']
df1.rename(columns= {'UnitPrice': 'AmountSpent'},inplace=True)
df1.drop(['StockCode','Country','CustomerID', 'Quantity'],inplace=True,axis=1)
df1["InvoiceNo"] = pd.to_numeric(df1["InvoiceNo"],errors='coerce')
df1=df1.dropna()
df1.shape
# Out:
# (249796, 18)

# %%
df1 = df1.groupby(['InvoiceNo','hour','day_Friday', 'day_Monday', 
                   'day_Sunday','day_Thursday', 'day_Tuesday', 
                   'day_Wednesday']).agg('sum')

# %%
df1.reset_index(level=['hour','day_Friday', 
                       'day_Monday', 'day_Sunday','day_Thursday', 
                       'day_Tuesday', 'day_Wednesday'],inplace=True)
df1.head()
#drop customer ID
#standardize df
#groupby.agg sum invoice number , then invoiceNo as index
# Out:
#            hour  day_Friday  ...  Item_Class_set  Item_Class_vintage
# InvoiceNo                    ...
# 536365.0      8           0  ...               2                   0
# 536367.0      8           0  ...               0                   5
# 536368.0      8           0  ...               6                   0
# 536371.0      9           0  ...               0                   0
# 536373.0      9           0  ...               2                  12
#
# [5 rows x 17 columns]

# %%
df1["AmountSpent"] = pd.to_numeric(df1["AmountSpent"],errors='coerce')

df1.dtypes
# Out:
# hour                          int64
# day_Friday                   uint64
# day_Monday                   uint64
# day_Sunday                   uint64
# day_Thursday                 uint64
# day_Tuesday                  uint64
# day_Wednesday                uint64
# AmountSpent                 float64
# Item_Class_accessory          int64
# Item_Class_bag                int64
# Item_Class_boxes              int64
# Item_Class_decoration         int64
# Item_Class_home               int64
# Item_Class_miscellaneous      int64
# Item_Class_retrospot          int64
# Item_Class_set                int64
# Item_Class_vintage            int64
# dtype: object

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
df2 = min_max_scaler.fit_transform(df1)
df2 = pd.DataFrame(df2)

# %%
df2.rename(columns= {0: 'hour', 
1: 'day_Friday' ,
2: 'day_Monday' ,
3: 'day_Sunday' ,
4: 'day_Thursday' ,
5: 'day_Tuesday' ,
6: 'day_Wednesday' ,
7: 'AmountSpent' ,
8: 'Item_Class_accessory', 
9: 'Item_Class_bag',
10: 'Item_Class_boxes', #(0 or 1) 
11: 'Item_Class_decoration', 
12: 'Item_Class_home', 
13: 'Item_Class_miscellaneous',
14: 'Item_Class_retrospot' ,
15: 'Item_Class_set' ,
16: 'Item_Class_vintage'}, inplace=True)
df2.shape
# Out:
# (16026, 17)

# %%
df2.head()
# Out:
#        hour  day_Friday  ...  Item_Class_set  Item_Class_vintage
# 0  0.142857         0.0  ...        0.000512            0.000000
# 1  0.142857         0.0  ...        0.000000            0.000867
# 2  0.142857         0.0  ...        0.001536            0.000000
# 3  0.214286         0.0  ...        0.000000            0.000000
# 4  0.214286         0.0  ...        0.000512            0.002081
#
# [5 rows x 17 columns]

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=3)

pc = pca.fit_transform(df2)
ppc = pd.DataFrame(data = pc
             ,columns = ['pc1', 'pc2', 'pc3'])
ppc.head()  
new_data = pd.DataFrame(pc)

# %%
new_data
# Out:
#               0         1         2
# 0     -0.428507  0.741560 -0.261097
# 1     -0.428502  0.741558 -0.261105
# 2     -0.428512  0.741565 -0.261089
# 3     -0.424169  0.742460 -0.261363
# 4     -0.424167  0.742459 -0.261368
# 5     -0.424167  0.742456 -0.261371
# 6     -0.424167  0.742459 -0.261368
# 7     -0.424161  0.742444 -0.261384
# 8     -0.424180  0.742467 -0.261414
# 9     -0.424171  0.742464 -0.261362
# 10    -0.424168  0.742460 -0.261379
# 11    -0.424169  0.742460 -0.261370
# 12    -0.424152  0.742446 -0.261393
# 13    -0.424170  0.742465 -0.261367
# 14    -0.424175  0.742466 -0.261413
# 15    -0.423890  0.742309 -0.261783
# 16    -0.424160  0.742462 -0.261373
# 17    -0.419814  0.743238 -0.261829
# 18    -0.419828  0.743367 -0.261631
# 19    -0.419832  0.743369 -0.261629
# 20    -0.419836  0.743340 -0.261693
# 21    -0.419813  0.743349 -0.261668
# 22    -0.419827  0.743361 -0.261637
# 23    -0.419827  0.743353 -0.261650
# 24    -0.419825  0.743358 -0.261660
# 25    -0.419830  0.743370 -0.261627
# 26    -0.415487  0.744264 -0.261909
# 27    -0.415481  0.744256 -0.261918
# 28    -0.415477  0.744249 -0.261948
# 29    -0.415500  0.744270 -0.261932
# ...         ...       ...       ...
# 15996 -0.174084 -0.140865  0.409181
# 15997 -0.174080 -0.140855  0.409192
# 15998 -0.174083 -0.140859  0.409192
# 15999 -0.169759 -0.139932  0.408927
# 16000 -0.169736 -0.139955  0.408916
# 16001 -0.169746 -0.139955  0.408916
# 16002 -0.169738 -0.139966  0.408896
# 16003 -0.169737 -0.139973  0.408903
# 16004 -0.169743 -0.139951  0.408908
# 16005 -0.169743 -0.139959  0.408924
# 16006 -0.169744 -0.139957  0.408921
# 16007 -0.165383 -0.139061  0.408629
# 16008 -0.165400 -0.139057  0.408628
# 16009 -0.165407 -0.139043  0.408668
# 16010 -0.165375 -0.139067  0.408608
# 16011 -0.165414 -0.139042  0.408657
# 16012 -0.161045 -0.138139  0.408352
# 16013 -0.161055 -0.138149  0.408371
# 16014 -0.161066 -0.138147  0.408392
# 16015 -0.161038 -0.138159  0.408354
# 16016 -0.161053 -0.138177  0.408361
# 16017 -0.156710 -0.137253  0.408103
# 16018 -0.156723 -0.137252  0.408110
# 16019 -0.156709 -0.137267  0.408041
# 16020 -0.156727 -0.137243  0.408128
# 16021 -0.156728 -0.137240  0.408129
# 16022 -0.156725 -0.137239  0.408114
# 16023 -0.156707 -0.137245  0.408105
# 16024 -0.156708 -0.137262  0.408091
# 16025 -0.156727 -0.137248  0.408109
#
# [16026 rows x 3 columns]

# %%
pca.explained_variance_ratio_
# Out:
# array([0.23988089, 0.20826658, 0.18910512])

# %%
from sklearn import cluster
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans

# %%
model =cluster.KMeans()
visualizer=KElbowVisualizer(model,k=(2,12))
visualizer.fit(new_data)
visualizer.poof
# Out:
# <bound method Visualizer.poof of KElbowVisualizer(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7ffa035af588>,
#                  k=None, metric=None, model=None, timings=True)>

# %%
kmeans=KMeans(4)
df_cluster=kmeans.fit(ppc)
df_cluster.cluster_centers_
# Out:
# array([[-0.40956024,  0.74549275, -0.26229796],
#        [-0.14424858, -0.1277239 ,  0.40901419],
#        [-0.26268543, -0.62053772, -0.59544768],
#        [ 0.84504671,  0.10987659, -0.10805752]])

# %%
df1['labels']=df_cluster.fit_predict(ppc)
df1.labels.value_counts()
# Out:
# 0    6838
# 1    3462
# 2    2962
# 3    2764
# Name: labels, dtype: int64

# %%
cross = pd.crosstab(df1.hour,df1.labels)
#cross = cross.reset_index()
cross
# Out:
# labels     0    1    2    3
# hour
# 6          0    1    0    0
# 7          6    7    5    4
# 8        162   93   84   94
# 9        419  236  238  247
# 10       804  363  366  327
# 11       941  320  361  365
# 12      1253  508  536  468
# 13      1044  415  435  419
# 14       920  388  343  313
# 15       792  364  325  299
# 16       366  276  197  143
# 17       120  203   69   82
# 18         1  148    0    3
# 19         9  124    2    0
# 20         1   16    1    0

# %%
import seaborn as sns
sns.heatmap(cross.corr(), cmap='YlGnBu')

# %%
df2.pivot_table(index=["hour"], values=["AmountSpent"])
# Out:
#           AmountSpent
# hour
# 0.000000     0.000179
# 0.071429     0.015782
# 0.142857     0.013895
# 0.214286     0.014552
# 0.285714     0.015905
# 0.357143     0.013754
# 0.428571     0.013293
# 0.500000     0.013127
# 0.571429     0.012776
# 0.642857     0.013787
# 0.714286     0.013371
# 0.785714     0.013615
# 0.857143     0.021109
# 0.928571     0.009974
# 1.000000     0.036906

# %%
kmeans.labels_
# Out:
# array([2, 2, 2, ..., 0, 0, 0], dtype=int32)

# %%
df2_clusters = kmeans.fit(df2)

# %%
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram
import numpy as np
import matplotlib.pyplot as plt

df2_columns = [col for col in df2.columns.values]
df2_sample=df2[df2_columns].sample(n=100)
hier_clust=AgglomerativeClustering(linkage='ward')
df2_hier=hier_clust.fit(df2_sample)

def plot_dendrogram(model, **kwargs):
  children=model.children_
  distance=np.arange(children.shape[0])
  no_observations = np.arange(2,children.shape[0]+2)
  linkage_matrix = np.column_stack([children,distance,no_observations]).astype(float)
  dendrogram(linkage_matrix,**kwargs)
  
plot_dendrogram(df2_hier,labels=df2_hier.labels_)

# %%
df3 = df1.reset_index()

new_data['labels'] = df3.labels


new_data.head()
# Out:
#           0         1         2  labels
# 0 -0.428507  0.741560 -0.261097       2
# 1 -0.428502  0.741558 -0.261105       2
# 2 -0.428512  0.741565 -0.261089       2
# 3 -0.424169  0.742460 -0.261363       2
# 4 -0.424167  0.742459 -0.261368       2

# %%
new_data.boxplot(column=["labels",0,1,2])

# %%
import seaborn as sns
sns.set()
f, axes = plt.subplots(1, 3)


sns.boxplot(  y=0, x= "labels", data=new_data,  orient='v' , ax=axes[0])
sns.boxplot(  y=1, x= "labels", data=new_data,  orient='v' , ax=axes[1])
sns.boxplot(  y=2, x= "labels", data=new_data,  orient='v' , ax=axes[2])

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure()
ax = fig.add_subplot(111, projection='3d')

y_pred = df2_clusters.predict(df2)
plt.figure(figsize=(6,6))
ax.scatter(new_data[0], new_data[1],new_data[2] ,c=y_pred)


#centers = kmeans.cluster_centers_
#ax.scatter(centers[:, 0], centers[:, 1], centers[:,2], c='red', s=50, alpha=0.75)
plt.show()

# %%
fig=plt.figure()
ax = fig.add_subplot(111)

colors=np.array(['blue','seagreen','purple','cyan'])

y_pred = df2_clusters.predict(df2)
plt.figure(figsize=(6,6))
ax.scatter(new_data[0], new_data[1] ,c=colors[y_pred])


#centers = kmeans.cluster_centers_
#ax.scatter(centers[:, 0], centers[:, 1], centers[:,2], c='red', s=50, alpha=0.75)
plt.show()

# %%
new_data.labels.value_counts()
# Out:
# 1    6838
# 0    3462
# 2    2962
# 3    2764
# Name: labels, dtype: int64

# %%
#import seaborn as sns
sns.heatmap(df4.corr(), cmap='YlGnBu')

# %%
df4 = df2.drop(['hour', 'day_Friday', 'day_Monday', 'day_Sunday', 'day_Thursday',
       'day_Tuesday', 'day_Wednesday'],axis=1)
